# %%
# Рассмотрим простейший перцептрон для задачи классификации 2 образов

# %% [markdown]
# ![Screenshot from 2024-10-17 15-00-12.png](attachment:1fbf1571-0d30-4d24-97ac-de17b0a4d6c3.png)

# %%
# пример классификации векторов с помощью простейшего персептрона

# %%
# если функция активация дает рез = 1, то входный сигнал принадлежит классу C1
# -1 == C2

# 1 и -1 выдается в зависимости от значения x
# если сумма больше или равна нулю, значит C1, и наоборот

# %%
# из функции активации видно, что граница разделения классов это 0
# то есть при выполнении равенства(5) мы находимся на границе разделения 2 классов
# это же выражение можно записать в виде (6)

# получается прямая с угловым коэффициентом(7)
# т.е. (6) можно воспринимать как y=k*x

# %% [markdown]
# ![Screenshot from 2024-10-17 15-00-57.png](attachment:5a366476-341e-42a3-8506-e0c34cb779d7.png)

# %%
# т.е. получаем уравнение прямой, которая проходит через начало системы координат
# и относительно этой прямой можно определить множество точек класса C1 и C2

# %%
# для примера смоделируем 2 класса линейно разделимых образов, которые будут разделяться прямой x2 = 1 * x1
# для корректной классификации нужно выбрать веса нейронной сети (рис 1)
# веса w1 w2

# %%
# т.к. угловой коэфф (рис 7), должен быть равен 1, значит веса нужно взять одинаковые, но с разным знаком

# %%
# смещение

# %%
# может случаться смещение как ниже

# %% [markdown]
# ![download.png](attachment:5f090266-9e2f-4dd6-8bbc-c3250c04c4a1.png)

# %%
# в нейросетях добавляют вход для смещения разделяющей гиперплоскости, так называемый bias - порог
# значение которое смещает разделяющую прямую

# %%
# этот вход всегда будет иметь значение +1 и некий вес

# %% [markdown]
# ![download.png](attachment:ec21688d-d483-49ae-bb3b-673abd31410b.png)

# %%
# в этом случае прямая может быть записана так

# %% [markdown]
# ![download.png](attachment:29bc1662-6a7b-4e55-be23-a750e700cff2.png)

# %%
# третий весовой коэфф можно выбрать из такого условия

# %% [markdown]
# ![download.png](attachment:4091bce4-f692-4e71-9c1f-924ac8e741b5.png)

# %%
# вышеописанный простой перцептрон может описывать только линейно разделимые образы

# %%
# представим что образы распределены так

# %% [markdown]
# ![Screenshot from 2024-10-17 16-05-06.png](attachment:bc41ef53-c771-471e-ba0f-69a4a456a7c8.png)

# %%
# простой линией разделить не получится, тогда проведем 2 прямые

# %%
# какие нейронные сети способны на такие операции?

# каждая линия может быть представлена отдельным нейроном
# а результат их классификации объединяется выходным результирующим нейроном

# %%
# задачи по типу той, что на графике, называются задачи XOR
