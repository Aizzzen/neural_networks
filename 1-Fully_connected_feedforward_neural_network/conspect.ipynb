# %%
# Полносвязная нейронная сеть прямого распространения

# %%
# Простейшая нейронная сеть - перцептрон - упрощенное представление работы биологической сети, состоящей из нейронов и связями между ними

# %%
# Следовательно, в полносвязной сети каждый нейрон текущего слоя, связан с каждым нейроном следующего слоя
# А прямое распространение значит, что входной сигнал распространяется от входа к выхода, не имея обратных связей

# %% [markdown]
# ![Screenshot from 2024-10-17 14-17-27.png](attachment:57d26222-46b2-467c-8d27-6d3e029c7a85.png)

# %%
# Если между входным и выходным слоями имеются какие-то другие слои, то эти слои - скрытые

# %% [markdown]
# ![Screenshot from 2024-10-17 14-19-33.png](attachment:33fd2b97-5b3d-4da7-a5f5-83b471373157.png)

# %%
# у связей между нейронами есть веса - омега ij
# когда сигнал проходит по связи, то он умножается на этот вес
# w(ij) * x(i)

# %%
# Что из себя представляет каждый нейрон из нейронной сети

# %% [markdown]
# ![Screenshot from 2024-10-17 14-21-41.png](attachment:d63e7fa1-2750-489b-acb3-1836555bc25c.png)

# %%
# 1. перед входом в нейрон все входы суммируются с учетом их веса и формируется сумма
# 2. значение суммы подставляется в функцию
# 3. то, что вернет функция и будет выходом нейрона

# функция f(x) - функция активации нейрона
# в концепции перцептрона выбирается как пороговая

# %% [markdown]
# ![Screenshot from 2024-10-17 14-25-18.png](attachment:cae6b9fc-476b-4361-9d71-54b75f0692e3.png)

# %% [markdown]
# ![Screenshot from 2024-10-17 14-30-50.png](attachment:33bf5b5f-a245-47d0-a0d4-66af1b398f50.png)
