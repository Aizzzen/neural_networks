# %% [markdown]
# # 6.Когда останавливать процесс обучения

# %%
# Переобучение - что это и как этого избежать, критерии останова обучения

# %% [markdown]
# ![Screenshot from 2024-10-18 16-41-32.png](attachment:1315d4d7-90b8-4703-95bb-b065c65bb894.png)

# %%
# Переобучение - когда разделяющая плоскость слишком точно описывает класс из обучающей выборки
# в результате теряется обобщаящая способность НС

# %% [markdown]
# ![Screenshot from 2024-10-18 16-44-46.png](attachment:d586befb-fb82-47c0-9ad2-97f524961eb3.png)

# %%
# избыток нейронов ухудшает обобщающие способности

# в идеале число нейронов должно быть столько сколько хватает для решения поставленной задачи
# определить это можно только опытным путем, подбирая минимальное число нейронов, которое дает приемлемый результат

# %%
# Рекомендация 6 
# использовать минимальное необходимое число нейронов в НС

# %%
# для контроля переобучения есть 1 способ

# обучающая выборка разбивается на 2 подвыборки

# %% [markdown]
# ![Screenshot from 2024-10-18 16-50-33.png](attachment:4f49ca49-7de8-4d04-83f2-ab76e31244c4.png)

# %% [markdown]
# ![Screenshot from 2024-10-18 16-51-35.png](attachment:89150153-5be6-46ab-bdd3-b862bb217488.png)

# %%
# когда начинается расхождение графиков это сигнал что начинается переобучение
# в этом случае лучше остановить обучение и весовые коэфф-ы выбрать такие, которые были в момент расхождения

# %%
# Рекомендация 7
# разбивать все множество наблюдений на 3 выборки: обучающую, валидации, тестовую

# %% [markdown]
# # 7.Какие критерии качества обучения использовать

# %%
# Основные критерии
# Расхождение показателя качества для обучающей выборки и валидации
# От итерации к итерации показатель качества практически не меняется
# Происходит малое изменение весовых коэфф
# Достигли максимального числа итераций
