# %% [markdown]
# # Функции активации, критерии качества работы НС

# %% [markdown]
# ![Screenshot from 2024-10-18 17-33-17.png](attachment:7bea0308-d166-49be-ad98-7457904db82a.png)

# %%
# Какие функции активации стоит выбирать

# %%
# Уже известные функции активации

# %% [markdown]
# ![Screenshot from 2024-10-18 17-34-34.png](attachment:da2e7230-f848-4974-b0c1-122ebd54529b.png)

# %%
# Пороговая - используется редко из-за проблемы с производными

# Гипер. и логис. - применяются где небольшое число скрытых слоев(не более 7)
# они отличаются выходным диапазоном, а так схожи

# %%
# функция производная которой равна 1

# %% [markdown]
# ![Screenshot from 2024-10-18 17-39-59.png](attachment:dce10102-d843-42de-a91b-9054e3b1630d.png)

# %%
# Рекомендация 8
# при малом числе слоев можно использовать гиперболическую и сигмоидальную функции активации или ReLu
# при числе слоев от 8 и более - ReLu и ее вариации

# это касаетя только скрытых слоев
# функции для выходного слоя обычно меняются

# %% [markdown]
# ![Screenshot from 2024-10-18 17-48-31.png](attachment:20329356-f7f7-456d-8d5c-09f2f91428e1.png)

# %%
# как только используем softmax, то для контроля качества лучше всего использовать - перекрестную энтропию
# потому что она хороша сочетается с вышепоказанным преобразованием

# %%
# Рекомендация 9
# для задач регрессии у выходных нейронов использовать линейную (linear) функцию активации,
# для задач классификации не пересекающихся классов - softmax

# %% [markdown]
# # Критерии качества

# %% [markdown]
# ![Screenshot from 2024-10-18 18-33-05.png](attachment:ae0b6178-0b73-48c9-b98c-25d7e383a6ac.png)

# %% [markdown]
# ![Screenshot from 2024-10-18 18-34-14.png](attachment:6f05737d-650a-451e-84b6-12b257c1e549.png)

# %% [markdown]
# ![Screenshot from 2024-10-18 18-33-48.png](attachment:9a8f0723-4393-4bf8-820a-9090cae023e8.png)

# %% [markdown]
# # Построение НС - субъективный и творческий процесс. Здесь помогают опыт и базовые знания о том, как все работает
