# %%
# в предыдущих примерах веса были либо даны, либо математически выбраны
# в больших нейронных сетях ручной подбор весов становится невозможен
# возникает необходимость алгоритмы который бы сам подбирал эти связи

# такой процесс подбора связи и наз-ся процесс обучения нейронной сети

# %%
# один из распространенных подходов к обучению

# последовательное предъявление нейронной сети векторов наблюдений
# и последующая корректировка весов так, чтобы выходное значение было близко к требуемому отклику

# %%
# это обучение с учителем

# %% [markdown]
# ![Screenshot from 2024-10-17 22-35-44.png](attachment:a0f18e40-3971-4d7e-9e41-bd0e67e791ad.png)

# %%
# нет идеального алгоритма для такого обучения, с выявлением связей и их весов
# но на сегодняшний денб лучшим считается back propagation
# алгоритм обратного распространения ошибки

# который базируется на алгоритме градиентного спуска

# %%
# рассмотрим

# %% [markdown]
# ![Screenshot from 2024-10-17 22-38-45.png](attachment:f78bb0c8-daa6-451a-b9cd-b25bf2bc59be.png)

# %%
# чтобы обучить эту НС у нас есть:
# 1.ее структура
# 2.начальные веса связей
# 3.наблюдения и их желаемый отклик(d)

# %%
# сначала идет прямое распространение как в 1-м алгоритме
# затем сравниваем результат с ожидаемым откликом
# вычисляем ошибку(е)

# и запускается процесс обучения - процесс корректировки весов

# %% [markdown]
# ![Screenshot from 2024-10-17 22-42-39.png](attachment:a1e3996d-3054-45b7-80d2-36a48a78bfb6.png)

# %%
# процесс идет в обратном направлении

# %%
# в соотвествии с алгоритмом back propagation нужно вычислить локальный градиент для этого выходного нейрона
# по формуле

# %% [markdown]
# ![Screenshot from 2024-10-17 22-44-24.png](attachment:d72f5e0d-afda-46a5-adee-2e89ea85ebfa.png)

# %%
# теперь можно выполнять коррекцию весов для последнего слоя
# например w(^3)11

# %% [markdown]
# ![Screenshot from 2024-10-17 22-46-26.png](attachment:a8bf0207-62c5-4d4d-a5c8-e4feae27af0a.png)

# %%
# параметр лямбда подбирается вручную

# %% [markdown]
# ![Screenshot from 2024-10-17 22-48-17.png](attachment:984857cf-b883-4961-941e-f091e34cb9d6.png)

# %% [markdown]
# ![Screenshot from 2024-10-17 22-49-41.png](attachment:20807462-c8ad-48ce-bf46-ecb9f1c8a338.png)

# %% [markdown]
# ![Screenshot from 2024-10-17 22-50-05.png](attachment:def7398e-96c9-4627-92f0-dad9989ab79c.png)

# %%
# выполнена 1 итерация обучения

# %%
# делаем N раз и получившиеся веса будут каждый раз точнее описывать обучающую выборку

# %%
# обучим нейронку по данному условию

# %% [markdown]
# ![Screenshot from 2024-10-17 22-52-20.png](attachment:1ab19f4b-ecfb-4f75-b696-074bcbc9422b.png)

# %%
# активационная функция - гиперболический тангенс (и ее производная)
